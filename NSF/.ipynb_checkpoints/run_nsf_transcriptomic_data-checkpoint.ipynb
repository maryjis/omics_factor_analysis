# %%
# %%
import scanpy as sc
from matplotlib import pyplot as plt
from pandas import get_dummies
from tensorflow_probability import math as tm
tfk = tm.psd_kernels
# Out:
# 2026-04-01 12:15:11.466317: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
import tensorflow as tf
import tensorflow as tf
import tensorflow_probability as tfp
print(tf.__version__)        # нужно 2.5.0
print(tfp.__version__)       # нужно 0.13.0
# Out:
# 2.5.0
# 0.13.0

# %%
import tensorflow as tf

print("TF version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPUs visible to TF:", tf.config.list_physical_devices('GPU'))
print("Logical GPUs:", tf.config.list_logical_devices('GPU'))
# Out:
# TF version: 2.5.0
# Built with CUDA: True
# GPUs visible to TF: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]
# Logical GPUs: [LogicalDevice(name='/device:GPU:0', device_type='GPU'), LogicalDevice(name='/device:GPU:1', device_type='GPU'), LogicalDevice(name='/device:GPU:2', device_type='GPU'), LogicalDevice(name='/device:GPU:3', device_type='GPU')]
# 2026-04-01 12:15:12.488110: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2026-04-01 12:15:12.576250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 47.38GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:12.578094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:61:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.40GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:12.580691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:81:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.40GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:12.584320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:e1:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.40GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:12.584365: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2026-04-01 12:15:12.588193: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2026-04-01 12:15:12.588248: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2026-04-01 12:15:12.589581: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2026-04-01 12:15:12.589927: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2026-04-01 12:15:12.590925: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2026-04-01 12:15:12.591781: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2026-04-01 12:15:12.591961: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2026-04-01 12:15:12.612401: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3
# 2026-04-01 12:15:12.613365: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-01 12:15:13.376728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 47.38GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:13.378574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:61:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.40GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:13.381680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:81:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.40GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:13.383500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:e1:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.40GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-04-01 12:15:13.399276: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3
# 2026-04-01 12:15:13.399375: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2026-04-01 12:15:16.698018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2026-04-01 12:15:16.698081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3
# 2026-04-01 12:15:16.698093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y Y Y
# 2026-04-01 12:15:16.698101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N Y Y
# 2026-04-01 12:15:16.698109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   Y Y N Y
# 2026-04-01 12:15:16.698117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   Y Y Y N
# 2026-04-01 12:15:16.719002: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-04-01 12:15:16.719044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 25895 MB memory) -> physical GPU (device: 0, name: NVIDIA L40S, pci bus id: 0000:01:00.0, compute capability: 8.9)
# 2026-04-01 12:15:16.721381: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-04-01 12:15:16.721418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 25427 MB memory) -> physical GPU (device: 1, name: NVIDIA L40S, pci bus id: 0000:61:00.0, compute capability: 8.9)
# 2026-04-01 12:15:16.724747: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-04-01 12:15:16.724783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 17339 MB memory) -> physical GPU (device: 2, name: NVIDIA L40S, pci bus id: 0000:81:00.0, compute capability: 8.9)
# 2026-04-01 12:15:16.726856: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-04-01 12:15:16.726890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 17749 MB memory) -> physical GPU (device: 3, name: NVIDIA L40S, pci bus id: 0000:e1:00.0, compute capability: 8.9)

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"   # например, хотим использовать только вторую GPU

import tensorflow as tf
tf.debugging.set_log_device_placement(True)

print(tf.config.list_physical_devices("GPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import scanpy as sc

print("TF:", tf.__version__)
print("TFP:", tfp.__version__)
print("NumPy:", np.__version__)
print("Scanpy:", sc.__version__)

try:
    import gpflow
    print("GPflow:", gpflow.__version__)
except Exception as e:
    print("GPflow import failed:", repr(e))
# Out:
# TF: 2.5.0
# TFP: 0.13.0
# NumPy: 1.19.5
# Scanpy: 1.8.0
# GPflow import failed: ModuleNotFoundError("No module named 'gpflow'")

# %%
import inspect
from models import sf

print(sf.__file__)
print(inspect.getsource(sf.SpatialFactorization)[:4000])
# Out:
# /workspace/workspace/stereoseq_project/nsf-paper/models/sf.py
# class SpatialFactorization(tf.Module):
#   def __init__(self, J, L, Z, lik="poi", psd_kernel=tfk.MaternThreeHalves,
#                nugget=1e-5, length_scale=0.1, disp="default",
#                nonneg=False, isotropic=True, feature_means=None, **kwargs):
#     """
#     Non-negative process factorization
#
#     Parameters
#     ----------
#     J : integer scalar
#         Number of features in the multivariate outcome.
#     L : integer scalar
#         Number of desired latent Gaussian processes.
#     T : integer scalar
#         Number of desired non-spatial latent factors
#     Z : 2D numpy array
#         Coordinates of inducing point locations in input space.
#         First dimension: 'M' is number of inducing points.
#         Second dimension: 'D' is dimensionality of input to GP.
#         More inducing points= slower but more accurate inference.
#     lik: likelihood (Poisson or Gaussian)
#     disp: overdispersion parameter initialization.
#     --for Gaussian likelihood, the scale (stdev) parameter
#     --for negative binomial likelihood, the parameter phi such that
#       var=mean+phi*mean^2, i.e. phi->0 corresponds to Poisson, phi=1 to geometric
#     --for Poisson likelihood, this parameter is ignored and set to None
#     psd_kernel : an object of class PositiveSemidefiniteKernel, must accept a
#         length_scale parameter.
#     feature_means : if input data is centered (for lik='gau', nonneg=False)
#     """
#     super().__init__(**kwargs)
#     # self.is_spatial=True
#     self.lik = lik
#     self.isotropic=isotropic
#     M,D = Z.shape
#     self.Z = tf.Variable(Z, trainable=False, dtype=dtp, name="inducing_points")
#     self.nonneg = tf.Variable(nonneg, trainable=False, name="is_non_negative")
#     #variational parameters
#     with tf.name_scope("variational"):
#       self.delta = tf.Variable(rng.normal(size=(L,M)), dtype=dtp, name="mean") #LxM
#       _Omega_tril = self._init_Omega_tril(L,M,nugget=nugget)
#       # _Omega_tril = .01*tf.eye(M,batch_shape=[L],dtype=dtp)
#       self.Omega_tril=tv(_Omega_tril, tfb.FillScaleTriL(), dtype=dtp, name="covar_tril") #LxMxM
#     #GP hyperparameters
#     with tf.name_scope("gp_mean"):
#       if self.nonneg:
#         prior_mu, prior_sigma = misc.lnormal_approx_dirichlet(max(L,1.1))
#         self.beta0 = tf.Variable(prior_mu*tf.ones((L,1)), dtype=dtp,
#                                  name="intercepts")
#       else:
#         self.beta0 = tf.Variable(tf.zeros((L,1)), dtype=dtp, name="intercepts") #L
#       self.beta = tf.Variable(tf.zeros((L,D)), dtype=dtp, name="slopes") #LxD
#     with tf.name_scope("gp_kernel"):
#       self.nugget = tf.Variable(nugget, dtype=dtp, trainable=False, name="nugget")
#       self.amplitude = tv(np.tile(1.0,[L]), tfb.Softplus(), dtype=dtp, name="amplitude")
#       self._ls0 = length_scale #store for .reset() method
#       if self.isotropic:
#         self.length_scale = tv(np.tile(self._ls0,[L]), tfb.Softplus(),
#                                dtype=dtp, name="length_scale")
#       else:
#         self.scale_diag = tv(np.tile(np.sqrt(self._ls0),[L,D]),
#                              tfb.Softplus(), dtype=dtp, name="scale_diag")
#     #Loadings weights
#     if self.nonneg:
#       self.W = tf.Variable(rng.exponential(size=(J,L)), dtype=dtp,
#                            constraint=misc.make_nonneg, name="loadings") #JxL
#     else:
#       self.W = tf.Variable(rng.normal(size=(J,L)), dtype=dtp, name="loadings") #JxL
#     self.psd_kernel = psd_kernel #this is a class, not yet an object
#     #likelihood parameters, set defaults
#     self._disp0 = disp
#     self._init_misc()
#     self.Kuu_chol = tf.Variable(self.eval_Kuu_chol(self.get_kernel()), dtype=dtp, trainable=False)
#     if self.lik=="gau" and not self.nonneg:
#       self.feature_means = feature_means
#     else:
#       self.feature_means = None
#
#   @staticmethod
#   def _init_Omega_tril(L, M, nugget=None):
#     """
#     convenience function for initializing the batch of lower triangular
#     cholesky factors of the variational covariance matrices.
#     L: number of latent dimensions (factors)
#     M: n

# %%
#!pip install dill

# %%
from models import sf
from utils import misc,preprocess,training,postprocess,visualize

# %%
# slice_path = '../selected_slices/T1089_MT66_P0_Visual_Sub-CTX_b100_filtered.h5ad'

# %%
slice_path = 'data/T1099_MT67_7M_Visual_Sub-CTX_V12_b100_filtered_J2000.h5ad'

# %%
#%% Data loading
ad = sc.read_h5ad(slice_path)
X = ad.obsm["spatial"]

# %%
ad
# Out:
# AnnData object with n_obs × n_vars = 15073 × 2000
#     obs: 'pct_counts_mt', 'orig.ident', 'x', 'y', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'n_counts', 'sizefactor'
#     var: 'real_gene_name', 'n_cells', 'n_counts', 'mean_umi', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'deviance_poisson'
#     uns: 'bin_size', 'bin_type', 'key_record', 'log1p', 'merged', 'resolution', 'sn'
#     obsm: 'spatial'
#     layers: 'counts'

# %%
ad.layers['counts']
# Out:
# <15073x2000 sparse matrix of type '<class 'numpy.uint32'>'
# 	with 14330891 stored elements in Compressed Sparse Row format>

# %%
#raw count data for NSF
D,Dval = preprocess.anndata_to_train_val(ad, layer=None, train_frac=0.8,
                                         flip_yaxis=False)

# %%
D["Y"].shape
# Out:
# (12058, 2000)

# %%
D["X"].shape
# Out:
# (12058, 2)

# %%
Ntr,J = D["Y"].shape
Xtr = D["X"]
ad = ad[:Ntr,:]
#convert to tensorflow objects
Dtf = preprocess.prepare_datasets_tf(D,Dval=Dval)

# %%
# #%% Heatmap of true values
# hmkw1 = {"figsize":(8,1.9), "bgcol":"lightgray", "subplot_space":0.1, "marker":"s",
#         "s":2.9}
# Ftrue = ad.obsm["spfac"]
# fig,axes=visualize.multiheatmap(Xtr, Ftrue, (1,4), cmap="Blues", **hmkw1)

# %%
#%% Initialize inducing points
L = 10 #number of components
Z = misc.kmeans_inducing_pts(Xtr, 2000)
M = Z.shape[0] #number of inducing points
ker = tfk.MaternThreeHalves

# %%
print(type(ker))
print(ker)
# Out:
# <class 'abc.ABCMeta'>
# <class 'tensorflow_probability.python.math.psd_kernels.matern.MaternThreeHalves'>

# %%
print("J =", J)
print("L =", L)
print("Z shape =", Z.shape)
# Out:
# J = 2000
# L = 10
# Z shape = (2000, 2)

# %%
D["Y"].shape
# Out:
# (12058, 2000)

# %%
Z.shape
# Out:
# (2000, 2)

# %%
from matplotlib import pyplot as plt

# %%
print(type(ker))
print(ker)
# Out:
# <class 'abc.ABCMeta'>
# <class 'tensorflow_probability.python.math.psd_kernels.matern.MaternThreeHalves'>

# %%
Xtr.shape
# Out:
# (12058, 2)

# %%
plt.scatter(Xtr[:,0],Xtr[:,1],c=D["Y"][:,2],cmap="turbo")

# %%
Xtr.shape
# Out:
# (12058, 2)

# %%
D["Y"]
# Out:
# array([[0.        , 0.        , 0.7922943 , ..., 1.2287382 , 0.        ,
#         0.7922943 ],
#        [0.        , 1.2918276 , 1.2918276 , ..., 0.84144473, 0.84144473,
#         0.        ],
#        [0.6884143 , 0.        , 0.        , ..., 1.0922968 , 0.        ,
#         0.6884143 ],
#        ...,
#        [1.4958652 , 0.        , 0.        , ..., 1.8237095 , 0.        ,
#         1.0048869 ],
#        [0.        , 0.        , 0.        , ..., 0.        , 1.5471476 ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 1.1078185 , 0.7000598 ,
#         0.        ]], dtype=float32)

# %%
pp = "res/T1099-7M/NSF_T1099_{}_M{}".format(L,ker.__name__, M)

# %%
pp
# Out:
# 'res/T1099-7M/NSF_T1099_10_MMaternThreeHalves'

# %%
len(Dtf)
# Out:
# 3

# %%
with tf.device("/CPU:0"):
    fit = sf.SpatialFactorization(J, L, Z, lik="poi", psd_kernel=ker,
                                      nugget=1e-5, length_scale=0.1, disp="default",
                                      nonneg=True, isotropic=True,
                                      feature_means=None)
    fit.init_loadings(D["Y"], X=Xtr, sz=D["sz"], shrinkage=0.3)
    tro = training.ModelTrainer(fit, lr=0.01, pickle_path=pp, max_to_keep=3)
    # %time tro.train_model(*Dtf, S=3, verbose=True, num_epochs=10000, ckpt_freq=50, kernel_hp_update_freq=10,status_freq=10, span=100, tol=5e-5, pickle_freq=10, lr_reduce=0.5, maxtry=10)
    visualize.plot_loss(tro.loss)
# Out:
# 2026-04-01 12:16:22.187541: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Temporary checkpoint directory: /tmp/tmpno5j5ygi
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_probability/python/distributions/distribution.py:346: calling Poisson.__init__ (from tensorflow_probability.python.distributions.poisson) with interpolate_nondiscrete is deprecated and will be removed after 2021-02-01.
# Instructions for updating:
# The `interpolate_nondiscrete` flag is deprecated; instead use `force_probs_to_zero_outside_support` (with the opposite sense).
# 2026-04-01 12:16:49.995785: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2026-04-01 12:16:50.068808: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2445555000 Hz
# 0010 train: 1.559e+03, val: 1.566e+03
# 0020 train: 1.556e+03, val: 1.563e+03
# 0030 train: 1.554e+03, val: 1.562e+03
# 0040 train: 1.553e+03, val: 1.561e+03
# 0050 train: 1.552e+03, val: 1.560e+03
# 0060 train: 1.551e+03, val: 1.560e+03
# 0070 train: 1.551e+03, val: 1.559e+03
# 0080 train: 1.551e+03, val: 1.560e+03
# 0090 train: 1.550e+03, val: 1.559e+03
# 0100 train: 1.550e+03, val: 1.559e+03
# 0110 train: 1.550e+03, val: 1.559e+03, chg: 3.67e-05
# 0120 train: 1.550e+03, val: 1.559e+03, chg: 2.24e-05
# 0120 training complete, converged.
# CPU times: user 11h 30min 30s, sys: 4h 42min 13s, total: 16h 12min 43s
# Wall time: 13min 31s

# %%
from models import sf
from utils import misc,preprocess,training,postprocess,visualize

# %%
with tf.device("/CPU:0"):    
    insfh = postprocess.interpret_nsf(fit,Xtr,S=10,lda_mode=False)
    misc.pickle_to_file(insfh,"res/T1099-7M/insfh_T1099-7M_L10_M3000_spde.pickle")
    tgnames = [str(i) for i in range(1,L+1)]

# %%
hmkw = {"figsize":(15,6),"s":0.4,"marker":".","subplot_space":0,
        "spinecolor":"white"}

# %%
with tf.device("/CPU:0"): 
    fig,axes=visualize.multiheatmap(Xtr, np.sqrt(insfh["factors"]),
                                    (2,5), **hmkw)
    visualize.set_titles(fig, tgnames, x=0.03, y=.88, fontsize="small", c="white",
                         ha="left", va="top")
    fig.savefig("res/T1099-7M/T1099-7M_heatmap_nsf10_spde_spat.png",
                bbox_inches='tight', dpi=300)

# %%
#%% Top genes for each latent dimension
with tf.device("/CPU:0"): 
    W = insfh["loadings"]#*insf["totals"][:,None]
    W[np.isnan(W)] = 0.0
    topgenes = W.argmax(axis=0).tolist()
    tgnames = ad.var.index[topgenes]
    Ytg = D["Y"][:,topgenes]/D["sz"]
    fig,axes=visualize.multiheatmap(Xtr, np.sqrt(Ytg), (2,5), **hmkw)
    visualize.set_titles(fig, tgnames, x=0.02, y=.88, fontsize="x-small", c="white",
                         ha="left", va="top")
    fig.savefig("res/T1099-7M/T1099-7M_heatmap_nsfh20_spde_spat_genes.png",
                bbox_inches='tight', dpi=300)

# %%
import pandas as pd

# %%
#save loadings to disk for further interpretation
with tf.device("/CPU:0"): 
    # W = W*insfh["totals"][:,None]
    Wdf=pd.DataFrame(W, index=ad.var.index, columns=range(1,L+1))
    Wdf.to_csv("res/T1099-7M/T1099-7M_nsfh20_spde_loadings.csv")

# %%
Wdf[1].sort_values()
# Out:
# GFAP      0.000000
# APOD      0.000000
# IGFBP5    0.000000
# GSN       0.000000
# TLE4      0.000000
#             ...
# IGFBP4    0.359218
# RARB      0.364145
# FOXP2     0.407541
# TRHDE     0.413913
# GABRG1    0.439844
# Name: 1, Length: 2000, dtype: float32
